# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# 1. It is assumed that the mean systolic blood pressure is μ = 120 mm Hg. In the Honolulu Heart Study, a sample of n = 100 people had an average systolic blood pressure of 130.1 mm Hg with a standard deviation of 21.21 mm Hg. Is the group significantly different (with respect to systolic blood pressure!) from the regular population?
#
#     - Set up the hypothesis test.
#     - Write down all the steps followed for setting up the test.
#     - Calculate the test statistic by hand and also code it in Python. It should be 4.76190. We will take a look at how to make decisions based on this calculated value.

# %%
blood_pressure= 120 
n=100
average_blood_pressure= 130.1
standard_deviation= 21.21

#Since we have the standard deviation we can proceed with a z-test, if we didnt knew i would proceed with a T-tes

# %%
#start by defining my hypotesis

H0= "The group is not significantly different (with respect to systolic blood pressure) from the regular population"
H1= "The group is significantly different (with respect to systolic blood pressure) from the regular population"

# %%
#getting the level of significance

alpha= 0.05

# %%
#calculate test statistic

z_test= (average_blood_pressure-blood_pressure)/ (standard_deviation/(n**0.5))
round(z_test,5)
# Out:
# 4.7619

# %%
# critical value (st vem de import scipy as st), with 95% confidence

critical_value= st.norm.ppf(1-alpha/2)
critical_value
# Out:
# 1.959963984540054

# %%
# calculate p-value

p_value= 2*(1-st.norm.cdf(z_test))
p_value
# Out:
# 1.9177418890681253e-06

# %%
if p_value < alpha:
    print("Reject the Null Hypothesis: Significant result.")
else:
    print("Mantain the Null Hypothesis: Not a significant result.")
# Out:
# Reject the Null Hypothesis: Significant result.

# %%
x = np.linspace(-3, 3, 100)
y = st.norm.pdf(x)
plt.plot(x, y, label="Standard Normal Distribution")
plt.fill_between(x, 0, y, where=(x < critical_value), color='red', alpha=0.3, label='Rejection Region')
plt.axvline(z_test, color='blue', linestyle='--', label=f'Test Statistic (z = {z_test:.5f})')
plt.axvline(critical_value, color='red', linestyle='--', label=f'Critical Value (z = {critical_value:.2f})')
plt.title("Hypothesis Testing Visualization")
plt.legend()
plt.show()

# %% [markdown]
# If you want to test for a significant difference (either higher or lower), use a two-tailed test. This is the assumption made in many scenarios unless specified otherwise.
#
# If you want to test specifically for a significant increase (higher systolic blood pressure), then it is a one-tailed test.

# %% [markdown]
# # One tailed analysis

# %%
blood_pressure_x= 120 
n_x=100
average_blood_pressure_x= 130.1
standard_deviation_x= 21.21

# %%
H0_x= "The group is not significantly different (with respect to systolic blood pressure) from the regular population"
H1_x= "The group is significantly different (with respect to systolic blood pressure) from the regular population"

# %%
alpha_x= 0.05

# %%
z_test_x= (average_blood_pressure_x/ blood_pressure_x)/(standard_deviation_x/n_x**0.5)
z_test_x
# Out:
# 0.5111582586830112

# %%
critical_value_x= st.norm.ppf(1-alpha_x) #right tailed because my z_test is positive
critical_value_x
# Out:
# 1.6448536269514722

# %%
p_value= (st.norm.cdf(z_test_x))
p_value
# Out:
# 0.6953798778109948

# %%
if p_value < alpha:
    print("Reject the Null Hypothesis: Significant result.")
else:
    print("Mantain the Null Hypothesis: Not a significant result.")
# Out:
# Mantain the Null Hypothesis: Not a significant result.

# %%
x = np.linspace(-3, 3, 100)
y = st.norm.pdf(x)
plt.plot(x, y, label="Standard Normal Distribution")
plt.fill_between(x, 0, y, where=(x < critical_value_x), color='red', alpha=0.3, label='Rejection Region')
plt.axvline(z_test_x, color='blue', linestyle='--', label=f'Test Statistic (z = {z_test_x:.5f})')
plt.axvline(critical_value_x, color='red', linestyle='--', label=f'Critical Value (z = {critical_value_x:.2f})')
plt.title("Hypothesis Testing Visualization")
plt.legend()
plt.show()
